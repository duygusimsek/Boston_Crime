# %%
import pandas as pd
import numpy as np

# %%
crime_data_to_load = "crimedata.csv"

# %%
crimedata = pd.read_csv(crime_data_to_load)
crimedata.head()
# Out:
#    OFFENSE_CODE       OFFENSE_DESCRIPTION DISTRICT  SHOOTING OCCURRED_ON_DATE  \
# 0           520    BURGLARY - RESIDENTIAL       B2         1    10/13/21 0:00
# 1          3114      INVESTIGATE PROPERTY       B2         0     5/12/21 0:00
# 2          3114      INVESTIGATE PROPERTY       B2         0     5/12/21 0:00
# 3          3114      INVESTIGATE PROPERTY       B2         0     3/29/21 0:00
# 4          3201  PROPERTY - LOST/ MISSING      E13         0     3/22/21 0:00
#
#    YEAR  MONTH DAY_OF_WEEK  HOUR           STREET  \
# 0  2021     10   Wednesday     0    SCHROEDER PLZ
# 1  2021      5   Wednesday     0    SCHROEDER PLZ
# 2  2021      5   Wednesday     0    SCHROEDER PLZ
# 3  2021      3      Monday     0  SCHROEDER PLAZA
# 4  2021      3      Monday     0    BLUE HILL AVE
#
#                                   Location
# 0  (42.33367921810846, -71.09187754618458)
# 1  (42.33367921810846, -71.09187754618458)
# 2  (42.33367921810846, -71.09187754618458)
# ...

# %%
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

import time
from sqlalchemy import create_engine

# %%
db_string = f"postgresql://postgres:{db_password}@localhost:5432/CRIME_DATA_2"

# %%
engine = create_engine(db_string)
crimedata.to_sql(name='Crime_final_1', con=engine, if_exists='replace')
# Out:
# 721

# %%
crime_reports_to_load= "crime_incident-reports_2018.csv"

# %%
crime_reports = pd.read_csv(crime_reports_to_load)
crime_reports.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# 0      I192077559          3115  Investigate Person  INVESTIGATE PERSON
# 1      I192077332           619             Larceny  LARCENY ALL OTHERS
# 2      I192076660          2629          Harassment          HARASSMENT
# 3      I192075386          2629          Harassment          HARASSMENT
# 4      I192075335          3208       Property Lost  PROPERTY - MISSING
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0       B3            468      NaN  2018-04-30 09:00:00  2018      4
# 1      E18            496      NaN  2018-03-06 08:00:00  2018      3
# 2       E5            662      NaN  2018-10-31 12:00:00  2018     10
# 3       A1             96      NaN  2018-04-09 08:43:00  2018      4
# 4       D4            132      NaN  2018-01-01 00:00:00  2018      1
#
#   DAY_OF_WEEK  HOUR    UCR_PART            STREET        Lat       Long  \
# ...

# %%
engine = create_engine(db_string)
crimedata.to_sql(name='Crime_final_1', con=engine, if_exists='replace')
